# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinothkanna93/PYTHON3-ASSIGNMENT-D25/blob/main/TASK0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EMAIL VALIDATION
# REGISTRATION OF USERNAME
print("Please Enter your valid email address for registration ")
s = str(input())
a = (s.count('@')==1 and s.count('&')<=1)
count = 0
for i in range(len(s)):
    if s[i] == '@':
        j = i+1
        while True:
            if s[j] == '.':
                break
            else:
                count += 1
                j += 1
b = (count >= 4)
count = 0
for i in range(len(s)):
    if s[i] == '@':
        break
    else:
        count += 1
c = (count >= 3)
d = (str(((s[::-1])[0:4])[::-1]) == '.com','.in')
if (('@' in s) and a and b and c and d ):
    print("Your email id is validated  and use your email address as username")
    file = open("Username.txt", 'a')
    file.write(s)
    file.close()
    print("Please create your password")
    def password_check(passwd):  
      SpecialSym =['$', '@', '#', '%''~', ':', "'", '+', '[', '\\', '@', '^', '{', '%', '(', '-', '"', '*', '|', ',', '&', '<', '`', '}', '.', '_', '=', ']', '!', '>', ';', '?', '#', '$', ')', '/']
      val = True
      if len(passwd) < 5:
        print('length should be at least 5')
        val = False     
      if len(passwd) > 16:
        print('length should be not be greater than 16')
        val = False       
      if not any(char.isdigit() for char in passwd):
        print('Password should have at least one numeral')
        val = False       
      if not any(char.isupper() for char in passwd):
        print('Password should have at least one uppercase letter')
        val = False       
      if not any(char.islower() for char in passwd):
        print('Password should have at least one lowercase letter')
        val = False       
      if not any(char in SpecialSym for char in passwd):
        print('Password should have at least one of the symbols $@#')
        val = False
      if val:
        return val
# Main method
      def main():
        passwd = input()
      if (password_check(passwd)):
        print("Password is valid")
      else:
        print("Invalid Password !!")  
#Driver Code        
    if __name__ == '__main__':
      main()
else:
   print(" Your email id is not valid  and please enter a valid email address")
   print("want to reset the password please press enter y key")
   a =input()
   if a =="y":
     print("Please Enter your valid email address for registration ")
s = str(input())
a = (s.count('@')==1 and s.count('&')<=1)
count = 0
for i in range(len(s)):
    if s[i] == '@':
        j = i+1
        while True:
            if s[j] == '.':
                break
            else:
                count += 1
                j += 1
b = (count >= 4)
count = 0
for i in range(len(s)):
    if s[i] == '@':
        break
    else:
        count += 1
c = (count >= 3)
d = (str(((s[::-1])[0:4])[::-1]) == '.com','.in')
if (('@' in s) and a and b and c and d ):
    print("Your email id is validated  and use your email address as username")
    file = open("Username.txt", 'a')
    file.write(s)
    file.close()
    print("Please create your password")
    def password_check(passwd):  
      SpecialSym =['$', '@', '#', '%''~', ':', "'", '+', '[', '\\', '@', '^', '{', '%', '(', '-', '"', '*', '|', ',', '&', '<', '`', '}', '.', '_', '=', ']', '!', '>', ';', '?', '#', '$', ')', '/']
      val = True
      if len(passwd) < 5:
        print('length should be at least 5')
        val = False     
      if len(passwd) > 16:
        print('length should be not be greater than 16')
        val = False       
      if not any(char.isdigit() for char in passwd):
        print('Password should have at least one numeral')
        val = False       
      if not any(char.isupper() for char in passwd):
        print('Password should have at least one uppercase letter')
        val = False       
      if not any(char.islower() for char in passwd):
        print('Password should have at least one lowercase letter')
        val = False       
      if not any(char in SpecialSym for char in passwd):
        print('Password should have at least one of the symbols $@#')
        val = False
      if val:
        return val
# Main method
      def main():
        passwd = input()
      if (password_check(passwd)):
        print("Password is valid")
      else:
        print("Invalid Password !!")  
#Driver Code        
    if __name__ == '__main__':
      main()
      if s == open('Username.txt').read():
       print('Username is already exist')
       print("your password is")
       print(passwd)
    else:
         print('user name not found please register ')
#else:
  #print("Thank you")
# Out:
# Please Enter your valid email address for registration
# vin@.in
#  Your email id is not valid  and please enter a valid email address
# want to reset the password please press enter y key
# y
# Please Enter your valid email address for registration
# vin@gmail.com
# Your email id is validated  and use your email address as username
# Please create your password
# vVin@98
# Password is valid

# %% [markdown]
# #EMAIL VALIDATION
# # REGISTRATION OF USERNAME
# print("Please Enter your valid email address for registration ")
# s = str(input())
# a = (s.count('@')==1 and s.count('&')<=1)
# count = 0
# for i in range(len(s)):
#     if s[i] == '@':
#         j = i+1
#         while True:
#             if s[j] == '.':
#                 break
#             else:
#                 count += 1
#                 j += 1
# b = (count >= 4)
# count = 0
# for i in range(len(s)):
#     if s[i] == '@':
#         break
#     else:
#         count += 1
# c = (count >= 3)
# #print(c)
# d = (str(((s[::-1])[0:4])[::-1]) == '.com','.in')
# if (('@' in s) and a and b and c and d ):
#     print("Your email id is validated  and use your email address as username")
# else:
#     print(" Your email id is not valid  and please enter a valid email address")
# print("Please create your password ")
# def password_check(passwd):
#
#     SpecialSym =['$', '@', '#', '%''~', ':', "'", '+', '[', '\\', '@', '^', '{', '%', '(', '-', '"', '*', '|', ',', '&', '<', '`', '}', '.', '_', '=', ']', '!', '>', ';', '?', '#', '$', ')', '/']
#     val = True
#     if len(passwd) < 5:
#         print('length should be at least 5')
#         val = False
#     if len(passwd) > 16:
#         print('length should be not be greater than 16')
#         val = False
#
#     if not any(char.isdigit() for char in passwd):
#         print('Password should have at least one numeral')
#         val = False
#
#     if not any(char.isupper() for char in passwd):
#         print('Password should have at least one uppercase letter')
#         val = False
#
#     if not any(char.islower() for char in passwd):
#         print('Password should have at least one lowercase letter')
#         val = False
#
#     if not any(char in SpecialSym for char in passwd):
#         print('Password should have at least one of the symbols $@#')
#         val = False
#     if val:
#         return val
# # Main method
# def main():
#     passwd = input()
#     if (password_check(passwd)):
#         print("Password is valid")
#     else:
#         print("Invalid Password !!")
# file = open("Username.txt", 'a')
# file.write(s)
# file.close()
# f = open("password.txt", 'a')
# f.write(passwd)
# f.close()
# print("want to reset the password please press enter y key")
# a =input()
# if a =="y":
#   if s == open('Username.txt').read():
#     print('Username is already exist')
#     print("your password is")
#     f=open("password.txt",'r')
#     print(f.read())
#   else:
#     print('user name not found please register ')
# else:
#   print("Thank you")
# #Driver Code
# if __name__ == '__main__':
#    main()
